# %% [markdown]
# <a href="https://colab.research.google.com/github/kashishgidwani/Python/blob/main/working_on_datasets_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from datetime import datetime
pd.date_range(start='2/2/2019',end='2/8/2019')
# Out:
# DatetimeIndex(['2019-02-02', '2019-02-03', '2019-02-04', '2019-02-05',
#                '2019-02-06', '2019-02-07', '2019-02-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
date_rg=pd.date_range(start='1/1/2019',end='1/8/2019',freq='H')
date_rg
# Out:
# DatetimeIndex(['2019-01-01 00:00:00', '2019-01-01 01:00:00',
#                '2019-01-01 02:00:00', '2019-01-01 03:00:00',
#                '2019-01-01 04:00:00', '2019-01-01 05:00:00',
#                '2019-01-01 06:00:00', '2019-01-01 07:00:00',
#                '2019-01-01 08:00:00', '2019-01-01 09:00:00',
#                ...
#                '2019-01-07 15:00:00', '2019-01-07 16:00:00',
#                '2019-01-07 17:00:00', '2019-01-07 18:00:00',
#                '2019-01-07 19:00:00', '2019-01-07 20:00:00',
#                '2019-01-07 21:00:00', '2019-01-07 22:00:00',
#                '2019-01-07 23:00:00', '2019-01-08 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq='H')

# %%
df=pd.DataFrame({"date":['2016-6-10 20:30:0','2016-7-1 19:45:30','2013-10-12 4:5:1'],'value':[2,3,4]})
df
# Out:
#                 date  value
# 0  2016-6-10 20:30:0      2
# 1  2016-7-1 19:45:30      3
# 2   2013-10-12 4:5:1      4

# %%
df['date']=pd.to_datetime(df['date'])
df
# Out:
#                  date  value
# 0 2016-06-10 20:30:00      2
# 1 2016-07-01 19:45:30      3
# 2 2013-10-12 04:05:01      4

# %%
df=pd.DataFrame({"Name":['Kashish','sakshi','deekshi','tanaya','vinnie'],'DOB':['11-21-2005','12-16-2007','05-26-2002','11-19-2003','11-27-2015']})
df['DOB']=pd.to_datetime(df['DOB'])
df
# Out:
#       Name        DOB
# 0  Kashish 2005-11-21
# 1   sakshi 2007-12-16
# 2  deekshi 2002-05-26
# 3   tanaya 2003-11-19
# 4   vinnie 2015-11-27

# %%
today=pd.to_datetime('today')
df['age']=today.year-df['DOB'].dt.year
df
# Out:
#       Name        DOB  age
# 0  Kashish 2005-11-21   18
# 1   sakshi 2007-12-16   16
# 2  deekshi 2002-05-26   21
# 3   tanaya 2003-11-19   20
# 4   vinnie 2015-11-27    8

# %%
df['year']=df['DOB'].dt.year
df['month']=df['DOB'].dt.month
df['day']=df['DOB'].dt.day
df
# Out:
#       Name        DOB  age  year  month  day
# 0  Kashish 2005-11-21   18  2005     11   21
# 1   sakshi 2007-12-16   16  2007     12   16
# 2  deekshi 2002-05-26   21  2002      5   26
# 3   tanaya 2003-11-19   20  2003     11   19
# 4   vinnie 2015-11-27    8  2015     11   27

# %%
df=df.set_index(['DOB'])
df
# Out:
#                Name  age  year  month  day
# DOB
# 2005-11-21  Kashish   18  2005     11   21
# 2007-12-16   sakshi   16  2007     12   16
# 2002-05-26  deekshi   21  2002      5   26
# 2003-11-19   tanaya   20  2003     11   19
# 2015-11-27   vinnie    8  2015     11   27

# %%
df.loc['2005']
# Out:
#                Name  age  year  month  day
# DOB
# 2005-11-21  Kashish   18  2005     11   21

# %%
df.loc['2005','age'].sum()
# Out:
# 18

# %%
df['2005'].groupby('month').sum()
# Out:
# <ipython-input-13-286fd7380b2d>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2005'].groupby('month').sum()
# <ipython-input-13-286fd7380b2d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df['2005'].groupby('month').sum()
#        age  year  day
# month
# 11      18  2005   21

# %%
df.groupby('month').sum()
# Out:
# <ipython-input-14-ee1140bcb467>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('month').sum()
#        age  year  day
# month
# 5       21  2002   26
# 11      46  6023   67
# 12      16  2007   16

# %%
cond=df.index.month==11
df[cond]
# Out:
#                Name  age  year  month  day
# DOB
# 2005-11-21  Kashish   18  2005     11   21
# 2003-11-19   tanaya   20  2003     11   19
# 2015-11-27   vinnie    8  2015     11   27

# %%
import json
import pandas as pd

# %%
df=pd.read_json('/content/sampledata.json')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
