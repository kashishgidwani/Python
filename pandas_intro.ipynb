# %% [markdown]
# <a href="https://colab.research.google.com/github/kashishgidwani/Python/blob/main/pandas_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#empty data frame is created
df=pd.DataFrame()
print(df)
#use separate lists to store data
df['Name']=['Kashish','Sakshi','Deekshi']
df['Age']=[17,15,21]
df['Gender']=['F','F','F']
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#       Name  Age Gender
# 0  Kashish   17      F
# 1   Sakshi   15      F
# 2  Deekshi   21      F

# %%
import pandas as pd
#use dictionary to store data
data={'subj':['Maths','Science','Social Science','Computer Science'],'marks':[99,88,95,99],'grade':('A','B','A','A')}
data
df=pd.DataFrame(data)
df
# Out:
#                subj  marks grade
# 0             Maths     99     A
# 1           Science     88     B
# 2    Social Science     95     A
# 3  Computer Science     99     A

# %%
filename="/content/weather.csv"
df=pd.read_csv(filename)
df
# Out:
#    month  avg_low  avg_high  record_high  record_low  avg_preci
# 0    Jan       58        42           74          22       2.95
# 1    Feb       61        45           78          26       3.02
# 2    Mar       65        48           84          25       2.34
# 3    Apr       67        50           92          28       1.02
# 4    May       71        53           98          35       0.48
# 5    Jun       75        56          107          41       0.11
# 6    Jul       77        58          105          44       0.00
# 7    Aug       77        59          102          43       0.03
# 8    Sep       77        57          103          40       0.17
# 9    Oct       73        54           96          34       0.81
# 10   Nov       64        48           84          30       1.70
# 11   Dec       58        42           73          21       2.56

# %%
#display first few rows
#print(df.head())
df.head(2)
# by deafult taakes first 5 rows
df.head()
# Out:
#   month  avg_low  avg_high  record_high  record_low  avg_preci
# 0   Jan       58        42           74          22       2.95
# 1   Feb       61        45           78          26       3.02
# 2   Mar       65        48           84          25       2.34
# 3   Apr       67        50           92          28       1.02
# 4   May       71        53           98          35       0.48

# %%
#similarly,df.tail()
df.tail(2)
# Out:
#    month  avg_low  avg_high  record_high  record_low  avg_preci
# 10   Nov       64        48           84          30       1.70
# 11   Dec       58        42           73          21       2.56

# %%
df.sample()
#gives any random sample
# Out:
#   month  avg_low  avg_high  record_high  record_low  avg_preci
# 8   Sep       77        57          103          40       0.17

# %% [markdown]
# ## **Description of Data**

# %%
df.shape
#no. of rows n cols
# Out:
# (12, 6)

# %%
#datatype of all columns
df.dtypes
# Out:
# month           object
# avg_low          int64
# avg_high         int64
# record_high      int64
# record_low       int64
# avg_preci      float64
# dtype: object

# %%
df.index
#for showing rows
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.columns
#shows all columns
# Out:
# Index(['month', 'avg_low', 'avg_high', 'record_high', 'record_low',
#        'avg_preci'],
#       dtype='object')

# %%
#sometimes dataset that you download might have extra blank spaces, to help with that lstrip() removes all extra spaces
df.columns=df.columns.str.lstrip()
df.columns
# Out:
# Index(['month', 'avg_low', 'avg_high', 'record_high', 'record_low',
#        'avg_preci'],
#       dtype='object')

# %%
#statistical summary of each column
df.describe()
# Out:
#          avg_low   avg_high  record_high  record_low  avg_preci
# count  12.000000  12.000000    12.000000   12.000000  12.000000
# mean   68.583333  51.000000    91.333333   32.416667   1.265833
# std     7.366488   6.060303    12.323911    8.240238   1.186396
# min    58.000000  42.000000    73.000000   21.000000   0.000000
# 25%    63.250000  47.250000    82.500000   25.750000   0.155000
# 50%    69.000000  51.500000    94.000000   32.000000   0.915000
# 75%    75.500000  56.250000   102.250000   40.250000   2.395000
# max    77.000000  59.000000   107.000000   44.000000   3.020000

# %%
#tells all important information about a dataset
#very important command just after reading the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        12 non-null     object
#  1   avg_low      12 non-null     int64
#  2   avg_high     12 non-null     int64
#  3   record_high  12 non-null     int64
#  4   record_low   12 non-null     int64
#  5   avg_preci    12 non-null     float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 704.0+ bytes

# %%
#sort the records by column
df.sort_values(by='record_high',ascending=False)
# Out:
#    month  avg_low  avg_high  record_high  record_low  avg_preci
# 5    Jun       75        56          107          41       0.11
# 6    Jul       77        58          105          44       0.00
# 8    Sep       77        57          103          40       0.17
# 7    Aug       77        59          102          43       0.03
# 4    May       71        53           98          35       0.48
# 9    Oct       73        54           96          34       0.81
# 3    Apr       67        50           92          28       1.02
# 2    Mar       65        48           84          25       2.34
# 10   Nov       64        48           84          30       1.70
# 1    Feb       61        45           78          26       3.02
# 0    Jan       58        42           74          22       2.95
# 11   Dec       58        42           73          21       2.56

# %%
sample_df=df.sample(5)
sample_df
# Out:
#   month  avg_low  avg_high  record_high  record_low  avg_preci
# 5   Jun       75        56          107          41       0.11
# 2   Mar       65        48           84          25       2.34
# 0   Jan       58        42           74          22       2.95
# 3   Apr       67        50           92          28       1.02
# 7   Aug       77        59          102          43       0.03

# %%
sample_df.sort_index()
# Out:
#   month  avg_low  avg_high  record_high  record_low  avg_preci
# 0   Jan       58        42           74          22       2.95
# 2   Mar       65        48           84          25       2.34
# 3   Apr       67        50           92          28       1.02
# 5   Jun       75        56          107          41       0.11
# 7   Aug       77        59          102          43       0.03

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#     record_low  record_high month  avg_preci  avg_low  avg_high
# 0           22           74   Jan       2.95       58        42
# 1           26           78   Feb       3.02       61        45
# 2           25           84   Mar       2.34       65        48
# 3           28           92   Apr       1.02       67        50
# 4           35           98   May       0.48       71        53
# 5           41          107   Jun       0.11       75        56
# 6           44          105   Jul       0.00       77        58
# 7           43          102   Aug       0.03       77        59
# 8           40          103   Sep       0.17       77        57
# 9           34           96   Oct       0.81       73        54
# 10          30           84   Nov       1.70       64        48
# 11          21           73   Dec       2.56       58        42
