# %% [markdown]
# <a href="https://colab.research.google.com/github/kashishgidwani/Python/blob/main/working_on_datasets_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# Read sales2.csv file into a dataframe

# %%
filename='/content/sales2 (1).csv'
df=pd.read_csv(filename)
df2=df.copy()
df2
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  05-10-2012         3001         5002
# 1    70009     270.65  09-10-2012         3001         5005
# 2    70002      65.26  05-10-2012         3005         5001
# 3    70004     110.50  08-17-2012         3001         5003
# 4    70007     948.50  10-09-2012         3005         5002
# 5    70005    2400.60  07-27-2012         3001         5001
# 6    70008    5760.00  10-09-2012         3005         5001
# 7    70010    1983.43  10-10-2012         3001         5006
# 8    70003    2480.40  10-10-2012         3005         5003
# 9    70012     250.45  06-17-2012         3001         5002
# 10   70011      75.29  07-08-2012         3005         5007
# 11   70013    3045.60  04-25-2012         3005         5001

# %% [markdown]
# Display the first few records

# %%
df2.head()
# Out:
#    ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001     150.50  05-10-2012         3001         5002
# 1   70009     270.65  09-10-2012         3001         5005
# 2   70002      65.26  05-10-2012         3005         5001
# 3   70004     110.50  08-17-2012         3001         5003
# 4   70007     948.50  10-09-2012         3005         5002

# %% [markdown]
# Describe the dataset

# %%
df2.describe()
# Out:
#              ord_no    purch_amt  customer_id  salesman_id
# count     12.000000    12.000000    12.000000    12.000000
# mean   70007.083333  1461.765000  3003.000000  5002.833333
# std        4.055486  1751.411698     2.088932     2.081666
# min    70001.000000    65.260000  3001.000000  5001.000000
# 25%    70003.750000   140.500000  3001.000000  5001.000000
# 50%    70007.500000   609.575000  3003.000000  5002.000000
# 75%    70010.250000  2420.550000  3005.000000  5003.500000
# max    70013.000000  5760.000000  3005.000000  5007.000000

# %% [markdown]
# Check for NA values

# %%
df2.isnull().sum()
# Out:
# ord_no         0
# purch_amt      0
# ord_date       0
# customer_id    0
# salesman_id    0
# dtype: int64

# %% [markdown]
# Plot a bar graph for ord_date Vs Purchase amount

# %%
df2.plot(x="ord_date",y="purch_amt",kind="bar")
plt.show()

# %% [markdown]
# Fetch the details of customer id 3001

# %%
df2.loc[df['customer_id']==3001]
# Out:
#    ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001     150.50  05-10-2012         3001         5002
# 1   70009     270.65  09-10-2012         3001         5005
# 3   70004     110.50  08-17-2012         3001         5003
# 5   70005    2400.60  07-27-2012         3001         5001
# 7   70010    1983.43  10-10-2012         3001         5006
# 9   70012     250.45  06-17-2012         3001         5002

# %% [markdown]
# Update the purchase amount of order Id 70012 as 500

# %%
df2.loc[df['ord_no']==70012,'purch_amt']=500
df2
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0    70001     150.50  05-10-2012         3001         5002
# 1    70009     270.65  09-10-2012         3001         5005
# 2    70002      65.26  05-10-2012         3005         5001
# 3    70004     110.50  08-17-2012         3001         5003
# 4    70007     948.50  10-09-2012         3005         5002
# 5    70005    2400.60  07-27-2012         3001         5001
# 6    70008    5760.00  10-09-2012         3005         5001
# 7    70010    1983.43  10-10-2012         3001         5006
# 8    70003    2480.40  10-10-2012         3005         5003
# 9    70012     500.00  06-17-2012         3001         5002
# 10   70011      75.29  07-08-2012         3005         5007
# 11   70013    3045.60  04-25-2012         3005         5001

# %% [markdown]
#  Retrieve the order no and customer id of the maximum purchase amount

# %%
df2.loc[(df.purch_amt==max(df.purch_amt)),['ord_no','customer_id','purch_amt']]
# Out:
#    ord_no  customer_id  purch_amt
# 6   70008         3005     5760.0

# %%
df2.loc[(df.purch_amt>1000),['ord_no','customer_id','purch_amt']]
# Out:
#     ord_no  customer_id  purch_amt
# 5    70005         3001    2400.60
# 6    70008         3005    5760.00
# 7    70010         3001    1983.43
# 8    70003         3005    2480.40
# 11   70013         3005    3045.60

# %%
df2['ord_date']=pd.to_datetime(df2['ord_date'])

# %%
df2[df2['ord_date'].dt.month==10]
# Out:
#    ord_no  purch_amt   ord_date  customer_id  salesman_id
# 4   70007     948.50 2012-10-09         3005         5002
# 6   70008    5760.00 2012-10-09         3005         5001
# 7   70010    1983.43 2012-10-10         3001         5006
# 8   70003    2480.40 2012-10-10         3005         5003

# %%
g=df2.groupby('customer_id')
for x in g:
  print(x)
# Out:
# (3001,    ord_no  purch_amt   ord_date  customer_id  salesman_id
# 0   70001     150.50 2012-05-10         3001         5002
# 1   70009     270.65 2012-09-10         3001         5005
# 3   70004     110.50 2012-08-17         3001         5003
# 5   70005    2400.60 2012-07-27         3001         5001
# 7   70010    1983.43 2012-10-10         3001         5006
# 9   70012     500.00 2012-06-17         3001         5002)
# (3005,     ord_no  purch_amt   ord_date  customer_id  salesman_id
# 2    70002      65.26 2012-05-10         3005         5001
# 4    70007     948.50 2012-10-09         3005         5002
# 6    70008    5760.00 2012-10-09         3005         5001
# 8    70003    2480.40 2012-10-10         3005         5003
# 10   70011      75.29 2012-07-08         3005         5007
# 11   70013    3045.60 2012-04-25         3005         5001)

# %%
gr_data=df2.groupby(['customer_id','salesman_id']).sum()
gr_data
# Out:
# <ipython-input-60-a241769653c3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gr_data=df2.groupby(['customer_id','salesman_id']).sum()
#                          ord_no  purch_amt
# customer_id salesman_id
# 3001        5001          70005    2400.60
#             5002         140013     650.50
#             5003          70004     110.50
#             5005          70009     270.65
#             5006          70010    1983.43
# 3005        5001         210023    8870.86
#             5002          70007     948.50
#             5003          70003    2480.40
#             5007          70011      75.29

# %%
gr_data['percentage']=gr_data.iloc[:,0]*100/sum(gr_data.iloc[:,0])
gr_data['percentage']=round(gr_data['percentage'],2)
gr_data
# Out:
#                          ord_no  purch_amt  percentage
# customer_id salesman_id
# 3001        5001          70005    2400.60        8.33
#             5002         140013     650.50       16.67
#             5003          70004     110.50        8.33
#             5005          70009     270.65        8.33
#             5006          70010    1983.43        8.33
# 3005        5001         210023    8870.86       25.00
#             5002          70007     948.50        8.33
#             5003          70003    2480.40        8.33
#             5007          70011      75.29        8.33

# %%
df2.rename(columns={'purch_amt':'purchaseAmount'})
# Out:
#     ord_no  purchaseAmount   ord_date  customer_id  salesman_id
# 0    70001          150.50 2012-05-10         3001         5002
# 1    70009          270.65 2012-09-10         3001         5005
# 2    70002           65.26 2012-05-10         3005         5001
# 3    70004          110.50 2012-08-17         3001         5003
# 4    70007          948.50 2012-10-09         3005         5002
# 5    70005         2400.60 2012-07-27         3001         5001
# 6    70008         5760.00 2012-10-09         3005         5001
# 7    70010         1983.43 2012-10-10         3001         5006
# 8    70003         2480.40 2012-10-10         3005         5003
# 9    70012          500.00 2012-06-17         3001         5002
# 10   70011           75.29 2012-07-08         3005         5007
# 11   70013         3045.60 2012-04-25         3005         5001
