# %% [markdown]
# <a href="https://colab.research.google.com/github/kashishgidwani/Python/blob/main/sample_questions_on_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %%
filename='/content/iris.csv'
df1=pd.read_csv(filename)
df2=df1.copy()
df2
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width         species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df2.head(10)
# Out:
#    Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width      species
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa
# 5   6           5.4          3.9           1.7          0.4  Iris-setosa
# 6   7           4.6          3.4           1.4          0.3  Iris-setosa
# 7   8           5.0          3.4           1.5          0.2  Iris-setosa
# 8   9           4.4          2.9           1.4          0.2  Iris-setosa
# 9  10           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df2[10:20]
# Out:
#     Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width      species
# 10  11           5.4          3.7           1.5          0.2  Iris-setosa
# 11  12           4.8          3.4           1.6          0.2  Iris-setosa
# 12  13           4.8          3.0           1.4          0.1  Iris-setosa
# 13  14           4.3          3.0           1.1          0.1  Iris-setosa
# 14  15           5.8          4.0           1.2          0.2  Iris-setosa
# 15  16           5.7          4.4           1.5          0.4  Iris-setosa
# 16  17           5.1          3.5           1.4          0.3  Iris-setosa
# 17  18           5.4          3.9           1.3          0.4  Iris-setosa
# 18  19           5.7          3.8           1.7          0.3  Iris-setosa
# 19  20           5.1          3.8           1.5          0.3  Iris-setosa

# %%
df2.drop_duplicates()
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width         species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df2.species.nunique()
# Out:
# 3

# %%
df2.sort_values(by='Sepal.Length', ascending=True)
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width         species
# 13    14           4.3          3.0           1.1          0.1     Iris-setosa
# 42    43           4.4          3.2           1.3          0.2     Iris-setosa
# 38    39           4.4          3.0           1.3          0.2     Iris-setosa
# 8      9           4.4          2.9           1.4          0.2     Iris-setosa
# 41    42           4.5          2.3           1.3          0.3     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 117  118           7.7          3.8           6.7          2.2  Iris-virginica
# 135  136           7.7          3.0           6.1          2.3  Iris-virginica
# 122  123           7.7          2.8           6.7          2.0  Iris-virginica
# 118  119           7.7          2.6           6.9          2.3  Iris-virginica
# 131  132           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 6 columns]

# %%
print(df2['Petal.Length'].sum())
print(df2['Petal.Length'].mean())
print(df2['Petal.Length'].mode())
# Out:
# 563.8
# 3.758666666666666
# 0    1.5
# Name: Petal.Length, dtype: float64

# %%
print(df2['Sepal.Width'].min())
print(df2['Sepal.Width'].max())
# Out:
# 2.0
# 4.4

# %%
df2.loc[df2['Petal.Length']>4]
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 106  107           4.9          2.5           4.5          1.7
# 84    85           5.4          3.0           4.5          1.5
# 90    91           5.5          2.6           4.4          1.2
# 94    95           5.6          2.7           4.2          1.3
# 88    89           5.6          3.0           4.1          1.3
# ..   ...           ...          ...           ...          ...
# 122  123           7.7          2.8           6.7          2.0
# 118  119           7.7          2.6           6.9          2.3
# 117  118           7.7          3.8           6.7          2.2
# 135  136           7.7          3.0           6.1          2.3
# 131  132           7.9          3.8           6.4          2.0
#
#              species
# 106   Iris-virginica
# 84   Iris-versicolor
# 90   Iris-versicolor
# 94   Iris-versicolor
# 88   Iris-versicolor
# ..               ...
# 122   Iris-virginica
# 118   Iris-virginica
# ...

# %%
df2.groupby("species")['Sepal.Length'].mean()
# Out:
# species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: Sepal.Length, dtype: float64

# %%
df2['total']=df2['Sepal.Width']+df2['Petal.Width']
df2
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 13    14           4.3          3.0           1.1          0.1
# 42    43           4.4          3.2           1.3          0.2
# 38    39           4.4          3.0           1.3          0.2
# 8      9           4.4          2.9           1.4          0.2
# 41    42           4.5          2.3           1.3          0.3
# ..   ...           ...          ...           ...          ...
# 122  123           7.7          2.8           6.7          2.0
# 118  119           7.7          2.6           6.9          2.3
# 117  118           7.7          3.8           6.7          2.2
# 135  136           7.7          3.0           6.1          2.3
# 131  132           7.9          3.8           6.4          2.0
#
#             species  total
# 13      Iris-setosa    3.1
# 42      Iris-setosa    3.4
# 38      Iris-setosa    3.2
# 8       Iris-setosa    3.1
# 41      Iris-setosa    2.6
# ..              ...    ...
# ...

# %%
df2['Petal.Length'].iloc[10:20] = np.nan
df2
# Out:
# <ipython-input-40-eea1214aa334>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Petal.Length'].iloc[10:20] = np.nan
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 13    14           4.3          3.0           1.1          0.1
# 42    43           4.4          3.2           1.3          0.2
# 38    39           4.4          3.0           1.3          0.2
# 8      9           4.4          2.9           1.4          0.2
# 41    42           4.5          2.3           1.3          0.3
# ..   ...           ...          ...           ...          ...
# 122  123           7.7          2.8           6.7          2.0
# 118  119           7.7          2.6           6.9          2.3
# 117  118           7.7          3.8           6.7          2.2
# ...

# %%
df2['Petal.Length'].fillna(round(df2['Petal.Length'].mean(),2), inplace=True)
df2
# Out:
#       Id  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 13    14           4.3          3.0           1.1          0.1
# 42    43           4.4          3.2           1.3          0.2
# 38    39           4.4          3.0           1.3          0.2
# 8      9           4.4          2.9           1.4          0.2
# 41    42           4.5          2.3           1.3          0.3
# ..   ...           ...          ...           ...          ...
# 122  123           7.7          2.8           6.7          2.0
# 118  119           7.7          2.6           6.9          2.3
# 117  118           7.7          3.8           6.7          2.2
# 135  136           7.7          3.0           6.1          2.3
# 131  132           7.9          3.8           6.4          2.0
#
#             species  total
# 13      Iris-setosa    3.1
# 42      Iris-setosa    3.4
# 38      Iris-setosa    3.2
# 8       Iris-setosa    3.1
# 41      Iris-setosa    2.6
# ..              ...    ...
# ...

# %%
plt.hist(df2['species'])
plt.style.use('ggplot')
plt.show()
